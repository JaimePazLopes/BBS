# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.flush_and_unmount()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "gdrive/My Drive/Colab Notebooks/processed.va.data"
dfva = pd.read_csv(path)
dfva["location"] = "Long Beach"
dfva.isna().sum()
# Out:
# age                          0
# sex                          0
# chest pain                   0
# resting blood pressure      56
# cholesteral                  7
# fasting blood sugar          7
# resting electrocardio        0
# max heart rate              53
# exercise induced angina     53
# ST depression               56
# ST slope                   102
# major verssels colored     198
# thallium stress            166
# diagnosis                    0
# location                     0
# dtype: int64

# %%
path = "gdrive/My Drive/Colab Notebooks/processed.cleveland.data"
dfclev = pd.read_csv(path)
dfclev["location"] = "Cleveland"
dfclev.isna().sum()
# Out:
# age                        0
# sex                        0
# chest pain                 0
# resting blood pressure     0
# cholesteral                0
# fasting blood sugar        0
# resting electrocardio      0
# max heart rate             0
# exercise induced angina    0
# ST depression              0
# ST slope                   0
# major verssels colored     4
# thallium stress            2
# diagnosis                  0
# location                   0
# dtype: int64

# %%
path = "gdrive/My Drive/Colab Notebooks/processed.hungarian.data"
dfhun = pd.read_csv(path)
dfhun["location"] = "Hungarian"
dfhun.isna().sum()
# Out:
# age                          0
# sex                          0
# chest pain                   0
# resting blood pressure       1
# cholesteral                 23
# fasting blood sugar          8
# resting electrocardio        1
# max heart rate               1
# exercise induced angina      1
# ST depression                0
# ST slope                   190
# major verssels colored     291
# thallium stress            266
# diagnosis                    0
# location                     0
# dtype: int64

# %%
path = "gdrive/My Drive/Colab Notebooks/processed.switzerland.data"
dfswi = pd.read_csv(path)
dfswi["location"] = "Switzerland"
dfswi.isna().sum()
# Out:
# age                          0
# sex                          0
# chest pain                   0
# resting blood pressure       2
# cholesteral                  0
# fasting blood sugar         75
# resting electrocardio        1
# max heart rate               1
# exercise induced angina      1
# ST depression                6
# ST slope                    17
# major verssels colored     118
# thallium stress             52
# diagnosis                    0
# location                     0
# dtype: int64

# %%
df = pd.concat([dfswi,dfhun,dfva,dfclev])
df.isna().sum()
# Out:
# age                          0
# sex                          0
# chest pain                   0
# resting blood pressure      59
# cholesteral                 30
# fasting blood sugar         90
# resting electrocardio        2
# max heart rate              55
# exercise induced angina     55
# ST depression               62
# ST slope                   309
# major verssels colored     611
# thallium stress            486
# diagnosis                    0
# location                     0
# dtype: int64

# %%
df["diagnosis basic"] = df["diagnosis"].apply(lambda x: 1 if x>=1 else 0)
sns.countplot(x="diagnosis basic", data=df)

# %%
g = sns.countplot(x="major verssels colored", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.countplot(x="thallium stress", hue="diagnosis basic",data=df)
g.legend_.set_title("CHD")

# %%
df = df.drop(["ST slope", "major verssels colored", "thallium stress"], axis=1)
df.isna().sum()
# Out:
# age                         0
# sex                         0
# chest pain                  0
# resting blood pressure     59
# cholesteral                30
# fasting blood sugar        90
# resting electrocardio       2
# max heart rate             55
# exercise induced angina    55
# ST depression              62
# diagnosis                   0
# location                    0
# diagnosis basic             0
# dtype: int64

# %%
dftest = df.dropna()
dftest.isna().sum()
# Out:
# age                        0
# sex                        0
# chest pain                 0
# resting blood pressure     0
# cholesteral                0
# fasting blood sugar        0
# resting electrocardio      0
# max heart rate             0
# exercise induced angina    0
# ST depression              0
# diagnosis                  0
# location                   0
# diagnosis basic            0
# dtype: int64

# %%
dftest.count()
# Out:
# age                        740
# sex                        740
# chest pain                 740
# resting blood pressure     740
# cholesteral                740
# fasting blood sugar        740
# resting electrocardio      740
# max heart rate             740
# exercise induced angina    740
# ST depression              740
# diagnosis                  740
# location                   740
# diagnosis basic            740
# dtype: int64

# %%
df=dftest
df
# Out:
#       age  sex  chest pain  ...  diagnosis     location  diagnosis basic
# 5    38.0  0.0         4.0  ...          1  Switzerland                1
# 7    38.0  1.0         3.0  ...          1  Switzerland                1
# 13   42.0  1.0         4.0  ...          2  Switzerland                1
# 15   43.0  1.0         4.0  ...          4  Switzerland                1
# 16   43.0  1.0         4.0  ...          2  Switzerland                1
# 19   46.0  1.0         4.0  ...          1  Switzerland                1
# 21   47.0  1.0         3.0  ...          3  Switzerland                1
# 23   47.0  1.0         4.0  ...          1  Switzerland                1
# 26   50.0  1.0         4.0  ...          3  Switzerland                1
# 27   50.0  1.0         4.0  ...          3  Switzerland                1
# 31   51.0  1.0         4.0  ...          3  Switzerland                1
# 34   51.0  1.0         4.0  ...          2  Switzerland                1
# ...

# %%
import seaborn as sns

sns.countplot(x="diagnosis", data=df)

# %%
sns.countplot(x="exercise induced angina", data=df)

# %%
sns.pairplot(df, corner=True, hue="diagnosis basic")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.kdeplot(x="age", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.kdeplot(x="resting blood pressure", hue="diagnosis basic",data=df)
g.legend_.remove()
#chest pain 	resting blood pressure 	cholesteral 	fasting blood sugar 	resting electrocardio 	max heart rate 	exercise induced angina

# %%
g = sns.kdeplot(x="cholesteral", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.kdeplot(x="fasting blood sugar", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.kdeplot(x="resting electrocardio", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.kdeplot(x="max heart rate", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
g = sns.kdeplot(x="exercise induced angina", hue="diagnosis basic",data=df)
g.legend_.remove()

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(),
            xticklabels=df.corr().columns.values,
            yticklabels=df.corr().columns.values, annot=True, cmap=sns.cm.rocket_r, fmt='.2f')

# %%
dftest = df[df["resting blood pressure"] != 0]
dftest = dftest[dftest["cholesteral"] != 0]
#dftest

# %%
dfdum = pd.get_dummies(dftest, columns=['resting electrocardio', "chest pain"], drop_first=True)
dfdum.head()
# Out:
#     age  sex  ...  chest pain_3.0  chest pain_4.0
# 0  28.0  1.0  ...               0               0
# 1  29.0  1.0  ...               0               0
# 3  30.0  0.0  ...               0               0
# 4  31.0  0.0  ...               0               0
# 5  32.0  0.0  ...               0               0
#
# [5 rows x 16 columns]

# %%
dfdum.dtypes
# Out:
# age                          float64
# sex                          float64
# resting blood pressure       float64
# cholesteral                  float64
# fasting blood sugar          float64
# max heart rate               float64
# exercise induced angina      float64
# ST depression                float64
# diagnosis                      int64
# location                      object
# diagnosis basic                int64
# resting electrocardio_1.0      uint8
# resting electrocardio_2.0      uint8
# chest pain_2.0                 uint8
# chest pain_3.0                 uint8
# chest pain_4.0                 uint8
# dtype: object

# %%
dfdum['age'] = dfdum['age'].astype(int)
dfdum['sex'] = dfdum['sex'].astype(int)
dfdum['resting blood pressure'] = dfdum['resting blood pressure'].astype(int)
dfdum['cholesteral'] = dfdum['cholesteral'].astype(int)
dfdum['fasting blood sugar'] = dfdum['fasting blood sugar'].astype(int)
dfdum['max heart rate'] = dfdum['max heart rate'].astype(int)
dfdum['exercise induced angina'] = dfdum['exercise induced angina'].astype(int)
dfdum.dtypes
# Out:
# age                            int64
# sex                            int64
# resting blood pressure         int64
# cholesteral                    int64
# fasting blood sugar            int64
# max heart rate                 int64
# exercise induced angina        int64
# ST depression                float64
# diagnosis                      int64
# location                      object
# diagnosis basic                int64
# resting electrocardio_1.0      uint8
# resting electrocardio_2.0      uint8
# chest pain_2.0                 uint8
# chest pain_3.0                 uint8
# chest pain_4.0                 uint8
# dtype: object

# %%
dfdum.head()
# Out:
#    age  sex  ...  chest pain_3.0  chest pain_4.0
# 0   28    1  ...               0               0
# 1   29    1  ...               0               0
# 3   30    0  ...               0               0
# 4   31    0  ...               0               0
# 5   32    0  ...               0               0
#
# [5 rows x 16 columns]

# %%
dfwork = dfdum.drop(["diagnosis", "location"], axis=1)
dfwork = dfwork.reset_index()
dfwork
# Out:
#      index  age  sex  ...  chest pain_2.0  chest pain_3.0  chest pain_4.0
# 0        0   28    1  ...               1               0               0
# 1        1   29    1  ...               1               0               0
# 2        3   30    0  ...               0               0               0
# 3        4   31    0  ...               1               0               0
# 4        5   32    0  ...               1               0               0
# 5        6   32    1  ...               1               0               0
# 6        7   32    1  ...               1               0               0
# 7        8   33    1  ...               0               1               0
# 8        9   34    0  ...               1               0               0
# 9       10   34    1  ...               1               0               0
# 10      11   34    1  ...               1               0               0
# 11      12   35    0  ...               0               0               0
# ...

# %%
y = dfwork["diagnosis basic"]
x = dfwork.drop("diagnosis basic", axis=1)

# %%
dfwork["diagnosis basic"].value_counts()
# Out:
# 0    347
# 1    314
# Name: diagnosis basic, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier #for the model
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz #plot tree
from sklearn.metrics import roc_curve, auc #for model evaluation
from sklearn.metrics import classification_report #for model evaluation
from sklearn.metrics import confusion_matrix #for model evaluation
from sklearn.model_selection import train_test_split #for data splitting

np.random.seed(123) #ensure reproducibility

# %%
#x = (x - np.min(x)) / (np.max(x) - np.min(x)).values

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = .2, random_state=10) #split the data

# %%
model = RandomForestClassifier(max_depth=5)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=5, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
estimator = model.estimators_[1]
feature_names = [i for i in X_train.columns]

y_train_str = y_train.astype('str')
y_train_str[y_train_str == '0'] = 'no disease'
y_train_str[y_train_str == '1'] = 'disease'
y_train_str = y_train_str.values

# %%
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = feature_names,
                class_names = y_train_str,
                rounded = True, proportion = True, 
                label='root',
                precision = 2, filled = True)

from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

from IPython.display import Image
Image(filename = 'tree.png')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
y_predict = model.predict(X_test)
y_pred_quant = model.predict_proba(X_test)[:, 1]
y_pred_bin = model.predict(X_test)

# %%
confusion_matrix(y_test, y_pred_bin)
# Out:
# array([[56,  9],
#        [ 8, 60]])

# %%
#auc(fpr, tpr)

# %%
accuracies = {}

lr = LogisticRegression()
lr.fit(X_train,y_train)
acc = lr.score(X_test,y_test)*100

y_pred_bin = lr.predict(X_test)

print("Test Accuracy {:.2f}%".format(acc))
# Out:
# Test Accuracy 80.45%
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
confusion_matrix(y_test, y_pred_bin)
# Out:
# array([[51, 14],
#        [12, 56]])

# %%
# KNN Model
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5)  # n_neighbors means k
knn.fit(X_train, y_train)
prediction = knn.predict(X_test)

print("{} NN Score: {:.2f}%".format(5, knn.score(X_test, y_test)*100))
# Out:
# 5 NN Score: 72.93%

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[52, 13],
#        [23, 45]])

# %%
# try ro find best k value
scoreList = []
for i in range(1,20):
    knn2 = KNeighborsClassifier(n_neighbors = i)  # n_neighbors means k
    knn2.fit(X_train, y_train)
    scoreList.append(knn2.score(X_test, y_test))
    
plt.plot(range(1,20), scoreList)
plt.xticks(np.arange(1,20,1))
plt.xlabel("K value")
plt.ylabel("Score")
plt.show()

acc = max(scoreList)*100
print("Maximum KNN Score is {:.2f}%".format(acc))
# Out:
# Maximum KNN Score is 72.93%

# %%
from sklearn.svm import SVC
svm = SVC(random_state = 1)
svm.fit(X_train, y_train)

prediction = svm.predict(X_test)

acc = svm.score(X_test,y_test)*100
print("Test Accuracy of SVM Algorithm: {:.2f}%".format(acc))
# Out:
# Test Accuracy of SVM Algorithm: 75.19%

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[58,  7],
#        [26, 42]])

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

prediction = dtc.predict(X_test)

acc = dtc.score(X_test, y_test)*100
print("Decision Tree Test Accuracy {:.2f}%".format(acc))
# Out:
# Decision Tree Test Accuracy 78.20%

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[52, 13],
#        [16, 52]])

# %%
# Random Forest Classification
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 1000, random_state = 1)
rf.fit(X_train, y_train)

prediction = rf.predict(X_test)

acc = rf.score(X_test,y_test)*100
print("Random Forest Algorithm Accuracy Score : {:.2f}%".format(acc))
# Out:
# Random Forest Algorithm Accuracy Score : 85.71%

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[55, 10],
#        [ 9, 59]])
